# %% [markdown]
# <a href="https://colab.research.google.com/github/pranshulab/Data_science_journey/blob/main/01_python/01_python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Operators***
# Arithmatic

# %%
#  +,-,*,/,%.//,**
a = 5
b = 32


print(a+b)
print(a-b)
print(a*b)
print(b/a)
print(b//a) # flow devision
print(b/a)
print(5**100)
# Out:
# 37
# -27
# 160
# 6.4
# 6
# 6.4
# 7888609052210118054117285652827862296732064351090230047702789306640625

# %%
print(32%5)
# Out:
# 2

# %% [markdown]
# **Assignment operator**

# %%
a = 23

# %% [markdown]
# **Compound assignment operator**

# %%
a  = 20

# %%
a += 20

# %%
a +=40

# %%
a
# Out:
# 80

# %%
a += 60

# %%
a
# Out:
# 260

# %% [markdown]
# **Comparision Operator**

# %%
# <, >, >=,<=, ==, !=

a =12
b= 12

# %%
print(a==b)
# Out:
# True

# %%
print(a != b)
# Out:
# False

# %%
print(a>b)
# Out:
# False

# %%
print(a<b)
# Out:
# False

# %%
print(23>23)
# Out:
# False

# %%
print(45<=45)
# Out:
# True

# %%
print(ord("A"))
# Out:
# 65

# %%
print(ord("B"))
# Out:
# 66

# %%
print("A">"B")
# Out:
# False

# %%
print("ABC" > "ACD")
# Out:
# False

# %%
print("A"> 35)  # can't compare string with intiger
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1101/3122183217.py in <cell line: 0>()
# ----> 1 print("A"> 35)
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %% [markdown]
# **Logocal Operator**

# %%
# and ( return true when both are true)
# or ( return true fi any one condition in true )
# not ( reverse the boolean value)

# %%
print(123 > 100  and 34 == 34 and 45 < 90)
# Out:
# True

# %%
print( 12!=12 or 23 == 45 or 10>5)
# Out:
# True

# %%
print( not 12 == 12)
# Out:
# False

# %%
print(126 > 130)
# Out:
# False

# %%
print((456 == 456) != (235 == 236))
# Out:
# True

# %%
print(12<10 or 45 == 56 or 69> 70 or 15 != 13)
# Out:
# True

# %%
print(True and bool(0))
# Out:
# False

# %% [markdown]
# **Conditional Statement**

# %%
if a>10:
  print("i will do task a ")
else:
  print(" i will do task b")
# Out:
# i will do task a
