# %% [markdown]
# <a href="https://colab.research.google.com/github/pranshulab/Data_science_journey/blob/main/DataVisualization/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Matplotlib Basics
#
# Subplots in matplotlib
#
# Object oriented way
#
# types of plots
#
# saving plots
#
# Working with images
#
# Designing (Optional)

# %%
import numpy as np
import pandas as  pd
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,5,11)
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y = x**2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)
plt.xlabel('x_axis')
plt.ylabel('y_axis')
plt.title('Demo')
# Out:
# Text(0.5, 1.0, 'Demo')

# %% [markdown]
# Subplots in Matplpotlib

# %%
plt.subplot(2,2,1)
plt.plot(x,y)
plt.subplot(2,2,4)
plt.plot(x,y)
plt.subplot(2,2,3)
plt.plot(y,x)
plt.subplot(2,2,2)
plt.plot(x**2,x**2)

# %% [markdown]
# **Object oriented way**

# %% [markdown]
# Matplotlib allow the aspect ratio, DPI and figure sixe to be specified when the figure object is created. you can use the figsixe and dpi keyword arguments
#
# figsize is a tupple of the width and height of the figure in inches dpi is the dots-per-inch (pixel per inch)

# %%
fig = plt.figure(figsize = (8,8), dpi = 100)
axis1 = fig.add_axes([0.1,0.1,1,1])
axis1.plot(x,y)
axis2 = fig.add_axes([0.5,0.7,0.3,0.3])
axis2.plot(y,x)

# %% [markdown]
# **Types of PLots**

# %%
plt.scatter(x,y)

# %%
from random import sample
data = sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([ 7., 10.,  6.,  6., 14., 11.,  9., 20.,  9.,  8.]),
#  array([ 13. , 111.1, 209.2, 307.3, 405.4, 503.5, 601.6, 699.7, 797.8,
#         895.9, 994. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7d48c45a47d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7d48c45a4a50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7d48c45a4690>],
#  'medians': [<matplotlib.lines.Line2D at 0x7d48c45a4cd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7d48c45a4e10>],
#  'means': []}

# %% [markdown]
# **Saving PLots**

# %%
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,1,1])
ax.plot(x,y)
plt.savefig("basicplot.png")

# %% [markdown]
# Working with images

# %%
import matplotlib.image as mpimg

# %%
from PIL import Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
image_path = "/content/drive/MyDrive/Colab Notebooks/DataVisualization/images.jpeg"

img = Image.open(image_path)
# img = mpimg.imread('/content/drive/MyDrive/Colab Notebooks/DataVisualization/images.jpeg')
plt.imshow(img)
# plt.axis("off")
plt.show()

# %%
cropped_img = img.crop((100,50,300,200))
plt.imshow(cropped_img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(199.5), np.float64(149.5), np.float64(-0.5))

# %% [markdown]
# **Designing**

# %%
plt.plot(x,y, color = 'red', lw = 2, ls = '--')
