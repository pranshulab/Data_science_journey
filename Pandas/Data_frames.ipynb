# %% [markdown]
# **Creating a Database**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Creating a database**

# %%
data = {
    'Name': ['john', 'Anna', 'Peter', 'Linda'],
    'city': ['New York', 'Paris', 'Berlin', 'London'],
    'Age': [28, 34, 29, 42],
    'salary': [65000, 70000, 62000, 85000]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#     Name      city  Age  salary
# 0   john  New York   28   65000
# 1   Anna     Paris   34   70000
# 2  Peter    Berlin   29   62000
# 3  Linda    London   42   85000

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
df2 = pd.DataFrame(data_list)
df2
# Out:
#        0   1         2      3
# 0   John  28  New York  65000
# 1   Anna  34     Paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000

# %%
columns = ['Name', 'Age', 'City', 'Salary']
df2 = pd.DataFrame(data_list, columns=columns)
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# **Selection and indexing of dataframe**

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2[["Name","City"]]
# Out:
#     Name      City
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %% [markdown]
# **Creating new columns**

# %%
df2["designation"] = ["doctor","Eng","doctor","Eng"]

# %%
df2
# Out:
#     Name  Age      City  Salary designation
# 0   John   28  New York   65000      doctor
# 1   Anna   34     Paris   70000         Eng
# 2  Peter   29    Berlin   62000      doctor
# 3  Linda   42    London   85000         Eng

# %%
df2.drop("designation", axis=1)
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2
# Out:
#     Name  Age      City  Salary designation
# 0   John   28  New York   65000      doctor
# 1   Anna   34     Paris   70000         Eng
# 2  Peter   29    Berlin   62000      doctor
# 3  Linda   42    London   85000         Eng

# %%
df2.drop("designation", axis=1, inplace=True)

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# removing cloumns

# %%
df2.drop(["City", "Salary"], axis=1)
# Out:
#     Name  Age
# 0   John   28
# 1   Anna   34
# 2  Peter   29
# 3  Linda   42

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.drop([0,1], axis=0)
# Out:
#     Name  Age    City  Salary
# 2  Peter   29  Berlin   62000
# 3  Linda   42  London   85000

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# **Selectingn rows**

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.loc[[0,1]]
# Out:
#    Name  Age      City  Salary
# 0  John   28  New York   65000
# 1  Anna   34     Paris   70000

# %%
df2.iloc[3]
# Out:
# Name       Linda
# Age           42
# City      London
# Salary     85000
# Name: 3, dtype: object

# %% [markdown]
# Selectiong subset of rows and columns

# %%
df.loc[[0,1]] [["Name","Age"]]
# Out:
#    Name  Age
# 0  john   28
# 1  Anna   34

# %%
df
# Out:
#     Name      city  Age  salary
# 0   john  New York   28   65000
# 1   Anna     Paris   34   70000
# 2  Peter    Berlin   29   62000
# 3  Linda    London   42   85000

# %%
df.loc[[2,3]] [["Name", "city"]]
# Out:
#     Name    city
# 2  Peter  Berlin
# 3  Linda  London

# %% [markdown]
# **Conditional Selection**

# %%
df
# Out:
#     Name      city  Age  salary
# 0   john  New York   28   65000
# 1   Anna     Paris   34   70000
# 2  Peter    Berlin   29   62000
# 3  Linda    London   42   85000

# %%
# i only want to see people whose age is above 30

# %%
df2[df["Age"]>30]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %%
df2[(df2["Age"] > 30) & (df2["City"] == 'Paris')]
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000
